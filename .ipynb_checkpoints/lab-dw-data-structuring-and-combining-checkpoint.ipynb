# %% [markdown]
# # Lab | Data Structuring and Combining Data

# %% [markdown]
# ## Challenge 1: Combining & Cleaning Data
#
# In this challenge, we will be working with the customer data from an insurance company, as we did in the two previous labs. The data can be found here:
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv
#
# But this time, we got new data, which can be found in the following 2 CSV files located at the links below.
#
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv
# - https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv
#
# Note that you'll need to clean and format the new data.
#
# Observation:
# - One option is to first combine the three datasets and then apply the cleaning function to the new combined dataset
# - Another option would be to read the clean file you saved in the previous lab, and just clean the two new files and concatenate the three clean datasets

# %%
import pandas as pd

#data1 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file1.csv")
#data1
#data1.dropna(inplace = True)
data2 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file2.csv")
data2
data2.dropna(inplace = True)
data3 = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/file3.csv")
data3
data3.dropna(inplace = True)

# %%
#data1
#data1["Customer Lifetime Value"] = data1["Customer Lifetime Value"].str.replace("%", "").astype(float)
#data2
#data2["Customer Lifetime Value"] = data2["Customer Lifetime Value"].str.replace("%", "").astype(float)
#data3
#data3["Customer Lifetime Value"] = data3["Customer Lifetime Value"].str.replace("%", "").astype(float)
#data1.drop_duplicates(inplace = True)
#data1
#data2.drop_duplicates(inplace = True)
#data2
#column_names = ['Customer', 'ST', 'GENDER', 'Education', 'Customer Lifetime Value', 'Income', 'Monthly Premium Auto', 'Number of Open Complaints', 'Policy Type', 'Vehicle Class', 'Total Claim Amount']
#std_rename = {"State": "ST",
#    "Gender": "GENDER"}
#data3.rename(columns=std_rename, inplace = True)

data_merged = pd.concat([data1, data2, data3], axis=0)
data_merged_null = data_merged.isnull().sum(axis=1)
data_cleaned = data_merged[data_merged_null <=3]
data_cleaned.drop_duplicates(subset="Customer", keep = False, inplace = True)
data_cleaned["Customer"].nunique()
data_cleaned
# Out:
#      Customer          ST GENDER Education Customer Lifetime Value   Income  \
# 1     QZ44356     Arizona      F  Bachelor               697953.59      0.0
# 2     AI49188      Nevada      F  Bachelor              1288743.17  48767.0
# 3     WW63253  California      M  Bachelor               764586.18      0.0
# 5     OC83172      Oregon      F  Bachelor               825629.78  62902.0
# 6     XZ87318      Oregon      F   College               538089.86  55350.0
# ...       ...         ...    ...       ...                     ...      ...
# 7065  LA72316  California      M  Bachelor             23405.98798  71941.0
# 7066  PK87824  California      F   College             3096.511217  21604.0
# 7067  TD14365  California      M  Bachelor             8163.890428      0.0
# 7068  UP19263  California      M   College             7524.442436  21941.0
# 7069  Y167826  California      M   College             2611.836866      0.0
#
# ...

# %% [markdown]
# # Challenge 2: Structuring Data

# %% [markdown]
# In this challenge, we will continue to work with customer data from an insurance company, but we will use a dataset with more columns, called marketing_customer_analysis.csv, which can be found at the following link:
#
# https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv
#
# This dataset contains information such as customer demographics, policy details, vehicle information, and the customer's response to the last marketing campaign. Our goal is to explore and analyze this data by performing data cleaning, formatting, and structuring.

# %%
demographics = pd.read_csv("https://raw.githubusercontent.com/data-bootcamp-v4/data/main/marketing_customer_analysis_clean.csv")
demographics.drop(columns=["unnamed:_0"], inplace = True)
pd.set_option('display.max_columns', None)
demographics
# Out:
#       customer       state  customer_lifetime_value response  coverage  \
# 0      DK49336     Arizona              4809.216960       No     Basic
# 1      KX64629  California              2228.525238       No     Basic
# 2      LZ68649  Washington             14947.917300       No     Basic
# 3      XL78013      Oregon             22332.439460      Yes  Extended
# 4      QA50777      Oregon              9025.067525       No   Premium
# ...        ...         ...                      ...      ...       ...
# 10905  FE99816      Nevada             15563.369440       No   Premium
# 10906  KX53892      Oregon              5259.444853       No     Basic
# 10907  TL39050     Arizona             23893.304100       No  Extended
# 10908  WA60547  California             11971.977650       No   Premium
# 10909  IV32877  California              6857.519928       No     Basic
#
#       education effective_to_date employmentstatus gender  income  \
# ...

# %%
demographics.columns
demographics.dtypes
# Out:
# customer                          object
# state                             object
# customer_lifetime_value          float64
# response                          object
# coverage                          object
# education                         object
# effective_to_date                 object
# employmentstatus                  object
# gender                            object
# income                             int64
# location_code                     object
# marital_status                    object
# monthly_premium_auto               int64
# months_since_last_claim          float64
# months_since_policy_inception      int64
# number_of_open_complaints        float64
# number_of_policies                 int64
# policy_type                       object
# policy                            object
# renew_offer_type                  object
# sales_channel                     object
# total_claim_amount               float64
# vehicle_class                     object
# ...

# %%
dem_pivot = pd.pivot_table(demographics, index = 'sales_channel', columns = "coverage", values = "customer_lifetime_value", aggfunc='sum').round(2)
dem_pivot["Total Revenue"] = dem_pivot.sum(axis = 1)
dem_pivot
# Out:
# coverage             Basic     Extended     Premium  Total Revenue
# sales_channel
# Agent          18206072.03  10872670.05  3979145.77    33057887.85
# Branch         12937006.16   8573781.91  2848413.15    24359201.22
# Call Center     9539122.05   5511302.20  2313864.12    17364288.37
# Web             7261344.27   3689845.14  1746443.49    12697632.90

# %%
#as you can see, agents produce the largest revenue, and the web service produces the lowest amount.

# %%
lifetime_pivot = pd.pivot_table(demographics, index = "education", columns = "gender", values = "customer_lifetime_value", aggfunc = "mean").round(2)
lifetime_pivot
# Out:
# gender                      F        M
# education
# Bachelor              7874.27  7703.60
# College               7748.82  8052.46
# Doctor                7328.51  7415.33
# High School or Below  8675.22  8149.69
# Master                8157.05  8168.83

# %% [markdown]
# 1. You work at the marketing department and you want to know which sales channel brought the most sales in terms of total revenue. Using pivot, create a summary table showing the total revenue for each sales channel (branch, call center, web, and mail).
# Round the total revenue to 2 decimal points.  Analyze the resulting table to draw insights.

# %%
lifetime_pivot2 = pd.pivot_table(demographics, index = "education", columns = "gender", values = "customer_lifetime_value", aggfunc = "sum").round(2)
lifetime_pivot2
# Out:
# gender                          F            M
# education
# Bachelor              13386258.11  12110061.83
# College               12460107.91  12851725.02
# Doctor                 1465701.78   1490482.06
# High School or Below  13793600.12  12680914.19
# Master                 3874600.25   3365559.06

# %%
#per the mean table, there is very little difference in the average customer lifetime value between the different sexes and education levels. However, something curious is that when you compare the sum, people who hold master's and doctor's degrees provide significantly less customer value than everybody else.

# %% [markdown]
# 2. Create a pivot table that shows the average customer lifetime value per gender and education level. Analyze the resulting table to draw insights.

# %% [markdown]
# ## Bonus
#
# You work at the customer service department and you want to know which months had the highest number of complaints by policy type category. Create a summary table showing the number of complaints by policy type and month.
# Show it in a long format table.

# %% [markdown]
# *In data analysis, a long format table is a way of structuring data in which each observation or measurement is stored in a separate row of the table. The key characteristic of a long format table is that each column represents a single variable, and each row represents a single observation of that variable.*
#
# *More information about long and wide format tables here: https://www.statology.org/long-vs-wide-data/*

# %%
# Your code goes here
